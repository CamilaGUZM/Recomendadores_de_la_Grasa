# %%
import os
os.chdir('..')

# %%
import numpy as np
import pandas as pd

from sklearn.compose import ColumnTransformer

from scripts.transformers import CheckColumnNames

# %%
data = pd.read_csv("data/datos_grasas_Tec.csv", encoding="latin1")
data.head()
# Out:
#    idDatosGrasas codigoGrasa     Aceite Base                        Espesante  \
# 0              1     Grasa_1  Semi-Sintetico     Complejo Sulfonato de Calcio
# 1              2     Grasa_2      Mineral HT     Complejo Sulfonato de Calcio
# 2              3     Grasa_3      Mineral HT     Complejo Sulfonato de Calcio
# 3              4     Grasa_4      Mineral HT     Complejo Sulfonato de Calcio
# 4              5     Grasa_5      Mineral HT  Complejo de Aluminio - Poliurea
#
#    Grado NLGI Consistencia  Viscosidad del Aceite Base a 40°C. cSt  \
# 0                      2.0                                   680.0
# 1                      1.5                                   460.0
# 2                      2.0                                   460.0
# 3                      2.0                                   220.0
# 4                      1.5                                   680.0
#
#   Penetración de Cono a 25°C, 0.1mm Punto de Gota, °C Estabilidad Mecánica, %  \
# ...

# %%
data_pdfs = pd.read_csv("data/datos_grasas_pdfs.csv", encoding="latin1")
data.head()
# Out:
#    idDatosGrasas codigoGrasa     Aceite Base                        Espesante  \
# 0              1     Grasa_1  Semi-Sintetico     Complejo Sulfonato de Calcio
# 1              2     Grasa_2      Mineral HT     Complejo Sulfonato de Calcio
# 2              3     Grasa_3      Mineral HT     Complejo Sulfonato de Calcio
# 3              4     Grasa_4      Mineral HT     Complejo Sulfonato de Calcio
# 4              5     Grasa_5      Mineral HT  Complejo de Aluminio - Poliurea
#
#    Grado NLGI Consistencia  Viscosidad del Aceite Base a 40°C. cSt  \
# 0                      2.0                                   680.0
# 1                      1.5                                   460.0
# 2                      2.0                                   460.0
# 3                      2.0                                   220.0
# 4                      1.5                                   680.0
#
#   Penetración de Cono a 25°C, 0.1mm Punto de Gota, °C Estabilidad Mecánica, %  \
# ...

# %%
transformer=CheckColumnNames()
X=transformer.fit_transform(data)
X.head()
# Out:
#    idDatosGrasas codigoGrasa     Aceite Base                        Espesante  \
# 0              1     Grasa_1  Semi-Sintetico     Complejo Sulfonato de Calcio
# 1              2     Grasa_2      Mineral HT     Complejo Sulfonato de Calcio
# 2              3     Grasa_3      Mineral HT     Complejo Sulfonato de Calcio
# 3              4     Grasa_4      Mineral HT     Complejo Sulfonato de Calcio
# 4              5     Grasa_5      Mineral HT  Complejo de Aluminio - Poliurea
#
#    Grado NLGI Consistencia  Viscosidad del Aceite Base a 40°C. cSt  \
# 0                      2.0                                   680.0
# 1                      1.5                                   460.0
# 2                      2.0                                   460.0
# 3                      2.0                                   220.0
# 4                      1.5                                   680.0
#
#   Penetración de Cono a 25°C, 0.1mm Punto de Gota, °C Estabilidad Mecánica, %  \
# ...

# %%
Y=transformer.transform(data_pdfs)
Y.head()
# Out:
#    idDatosGrasas                 codigoGrasa    Aceite Base  \
# 0             52             ANDEROL  FGCS-2  Aceite Blanco
# 1             53  DeloÂ® Grease EP 00 235212            NaN
# 2             54   DeloÂ® Grease EP 0 235211            NaN
# 3             55  DeloÂ® Grease EP 1 235209             NaN
# 4             56   DeloÂ® Grease EP 2 235208            NaN
#
#                       Espesante Grado NLGI Consistencia  \
# 0  Complejo Sulfonato de Calcio                       2
# 1             Complejo de Litio                       0
# 2             Complejo de Litio                       0
# 3             Complejo de Litio                       1
# 4             Complejo de Litio                       2
#
#    Viscosidad del Aceite Base a 40°C. cSt Penetración de Cono a 25°C, 0.1mm  \
# 0                                    95.0                       265 â 295
# 1                                   226.0                               415
# ...
